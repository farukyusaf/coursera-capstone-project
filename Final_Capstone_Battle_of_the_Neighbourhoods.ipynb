# %% [markdown]
# # **IBM Data Science – Capstone**
#
# **Choosing the Best Cities for Middle Eastern Eateries in Australia**:
#
# An exploratory analysis of Sydney, Melbourne, Canberra, Brisbane and Perth
#
# The notebook can be viewed here: https://colab.research.google.com/drive/1F7bI8IXsrmp3evGtEz1jfbBX2G75wEmf
#
#
#
# (A detailed report can be found on my Git repository.)

# %% [markdown]
# # **Importing Necessary Libraries Pandas, Numpy and Folium**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests 
from pandas.io.json import json_normalize #we will use this normalize our nested JSON file from Foursquare
import folium # Map library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # **As our project is Map intensive, we will just play around with Folium as see whether the map coordinates are working properly for Australia and Sydney for example**

# %%
Aus_m = folium.Map([-25.2743988, 133.7751312], zoom_start=5)
Aus_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# ERROR! Session/line number was not unique in database. History logging moved to new session 61

# %%
Sydney_m = folium.Map([-33.870453, 151.208755], zoom_start=10)
Sydney_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # **Once we are up and running, we will set up our foursquare API using our client ID and Secret, and combine 5 queries (for 5 cities) into one below. We will also limit the queries to each city to a 100.**
#
# **We also use the Foursquare distinct code for Middle Eastern restaurants:** 4bf58dd8d48988d115941735

# %%
CLIENT_ID = 'KEY HIDDEN FOR REVIEW' # your Foursquare ID
CLIENT_SECRET = 'KEY HIDDEN FOR REVIW' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
LIMIT = 100 #limiting queries to a 100
cities = ['Sydney, NSW', 'Melbourne, VIC', 'Perth, WA', 'Canberra, ACT', 'Brisbane, QLD'] #our five target cities and thier states
results = {}
for city in cities:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        city,
        LIMIT,
        "4bf58dd8d48988d115941735") # Foursquare Code for Middle Eastern Eateries
    results[city] = requests.get(url).json()

# %% [markdown]
# ## **In this step we are now normalising our Json data and creating a dictionary object with Name (of the Venue), Address, Lat and Long**

# %%
df_venues={}
for city in cities:
    venues = json_normalize(results[city]['response']['groups'][0]['items'])
    df_venues[city] = venues[['venue.name', 'venue.location.address', 'venue.location.lat', 'venue.location.lng']]
    df_venues[city].columns = ['Name', 'Address', 'Lat', 'Lng']

# %% [markdown]
# # **After normalizing our data, we get the Name, Address, Lat and Long coordinates**

# %%
df_venues
# Out:
# {'Brisbane, QLD':                                               Name  \
#  0                                             Naïm
#  1                          Gad's: Charcoal Chicken
#  2                                           Byblós
#  3   Arabella’s Charcoal and Middle Eastern Cuisine
#  4                        Sunshine Kebabs Underwood
#  5   Arabella's Charcoal and Middle Eastern Cuisine
#  6                                      Baba Ganouj
#  7                                  Watany Manoushi
#  8                                  Sinbad's Kebabs
#  9                         Baalbek Lebanese Cuisine
#  10                                            Naïm
#  11                                     1001 Nights
#  12                                     ISPA Kebabs
#  13                        Farah Persian Restaurant
#  14                                     Baba Ganouj
#  15                         Rockys Bakehouse & Cafe
#  16                       King Ahiram Lebanese Food
#  17                            NoNo's Lebanese Food
#
#                                                Address        Lat         Lng
#  0                                   14 Collingwood St -27.458005  152.994333
#  1                                                 NaN -27.560947  153.083769
#  2                           Shop 7.13, Portside Wharf -27.441268  153.069326
#  3                                 149-151 Boundary St -27.479606  153.012340
#  4                                                 NaN -27.609529  153.112593
#  5                                       1932 Logan Rd -27.557887  153.080813
#  6                                             Grey St -27.480853  153.022939
#  7                                                 NaN -27.560835  153.083558
#  8   Toowong Village (Shop G28, Level G), 9 Sherwoo... -27.485235  152.992670
#  9                              Junction & Wynnum Road -27.465703  153.079915
#  10                                   109 Melbourne St -27.475060  153.015840
#  11                             Shop 9, 229 Hawken Dr. -27.502510  153.006030
#  12                      Stafford City Shopping Centre -27.412674  153.012254
#  13                  1/391 Wickham Terrace, Springhill -27.560668  153.053856
#  14                 Shop 3, Riverside Centre, Eagle St -27.467557  153.030823
#  15                                        Kingston Rd -27.629702  153.118723
#  16                                   86-88 Vulture St -27.480886  153.012370
#  17                                    158 Musgrave Rd -27.454974  153.006669  ,
#  'Canberra, ACT':                                          Name                  Address  \
#  0                          Turkish Pide House              2 Lawry Pl.
#  1                            Star Kebab House          12 Dalby Street
#  2                                    Ali Baba               Woolley St
#  3                                    Ali Baba               Botany St.
#  4                      Charnwood Turkish Pide     Shop 11/ Charnwood P
#  5                                    Ali Baba          Westfield Woden
#  6                                    Ali Baba             102 Emu Bank
#  7                                    Ali Baba   Hyperdome, Anketell St
#  8                               Turkish Grill    9a/20 Gartside Street
#  9                             Turkish Delight             5 Weedon Cl.
#  10  Sultan's Turkish Pide Takeaway Restaurant       3/33 Hibberson St.
#  11                                   Ali Baba                 City Wlk
#  12                      Turkish Kebab & Pizza                 6 Rae St
#  13                               Saffron Room  57A Nellie Hamilton Ave
#  14                                    Saffron               Kennedy St
#
#            Lat         Lng
#  0  -35.252340  149.073450
#  1  -35.324118  149.155178
#  2  -35.249640  149.136886
#  3  -35.349961  149.088936
#  4  -35.204650  149.034070
#  5  -35.346343  149.086870
#  6  -35.237000  149.070880
#  7  -35.416247  149.067510
#  8  -35.405680  149.099540
#  9  -35.241656  149.063057
#  10 -35.185056  149.133638
#  11 -35.280271  149.133292
#  12 -35.236718  149.060751
#  13 -35.176828  149.134952
#  14 -35.316685  149.141210  ,
#  'Melbourne, VIC':                                    Name  \
#  0                       Kebabs R' Yummy
#  1                             Teta Mona
#  2                       Maha Restaurant
#  3                                 Kamel
#  4                                Tahini
#  5                      Persian Room 248
#  6                           Mama Rumaan
#  7                Flemington Kebab House
#  8                    Marmara Restaurant
#  9           Mr Lawrence (at) the London
#  10                          Just Falafs
#  11                           CBD Kebabs
#  12                              Achelya
#  13                               almina
#  14                               Boreks
#  15                     Agraba Mezze Bar
#  16                               Zaatar
#  17  Lezzet Contemporary Turkish Cuisine
#  18                        Biggie Smalls
#  19                 Abbout Falafel House
#  20                       Turkish Kebabs
#  21                     Miznon Melbourne
#  22                            Mecca Bah
#  23                                 SOUK
#  24                            Arabesque
#  25                             Almazett
#  26                     Casablanca Kebab
#  27                                 MoMo
#  28                       Kamil's Kebabs
#  29                  Kanzaman Restaurant
#  30                              Humbaba
#  31                         Mama Ganoush
#  32                            Kan Zaman
#  33                      The Kebab House
#  34                         Halal Kebabs
#  35                                Mawal
#  36                         King's Kebab
#  37                             Goz City
#  38            Anatolian Gozleme Kitchen
#  39                            Solidaire
#  40                               Cupido
#  41                              Sinbads
#  42                         Deccan Kebab
#  43                 Richmond Kebab House
#  44                   Ali's Jumbo Kebabs
#  45                    Lambs On Richmond
#  46                      The Kebab House
#  47                       Queen's Kebabs
#  48                          Stalactites
#  49                           Cafe Issus
#  50                           Roxy Kebab
#  51                            Arabesque
#  52                             Aghadeer
#  53                               Tavlin
#  54           Abla's Lebanese Restaurant
#  55             Laffa Bar Charcoal Grill
#  56                               Byblos
#  57                              Zurouna
#  58              A1 Lebanese Bakery Cafe
#  59        Min Zaman Lebanese Restaurant
#  60       Sahar Take Away Kebab & Bakery
#  61                         Persiangrill
#  62                         Pick A Pokit
#  63                             Leyalina
#  64                   The House of Mandi
#
#                                    Address        Lat         Lng
#  0                            192 Wells St -37.831966  144.969831
#  1                100A Lygon St, Brunswick -37.775450  144.971240
#  2                              21 Bond St -37.818221  144.962182
#  3                        19 Victoria Ave. -37.842094  144.952970
#  4                    518 Little Bourke St -37.814848  144.956856
#  5                             South Yarra -37.839459  144.995309
#  6                    Shed 9, Central Pier -37.816491  144.943757
#  7                     301 Racecourse Road -37.788333  144.930858
#  8                            68 Chapel St -37.855361  144.992888
#  9                            2 Princes St -37.841356  144.934725
#  10                      207 St Georges Rd -37.784270  144.982780
#  11                      2/546 Flinders St -37.820873  144.956173
#  12                               New Quay -37.814051  144.942786
#  13                                    NaN -37.815250  144.938170
#  14                  Queen Victoria Market -37.807053  144.959369
#  15                               Errol st -37.803616  144.949473
#  16                          365 Sydney Rd -37.745078  144.965825
#  17                         81 Brighton Rd -37.872730  144.989921
#  18                        86 Smith Street -37.805722  144.983158
#  19                        3/465 Sydney Rd -37.742570  144.966190
#  20                   286 Clarendon Street -37.833146  144.960593
#  21                       59 Hardware Lane -37.813390  144.960970
#  22                      55a Newquay Prom. -37.815452  144.941496
#  23                         13 Bligh Place -37.817126  144.963710
#  24   Shop 1, 1-3 Carre Street Elsternwick -37.885286  145.004288
#  25                     210 Balaclava Road -37.872258  145.022989
#  26                         61B Fitzroy St -37.861280  144.975350
#  27                         123 Collins St -37.814930  144.969590
#  28     Melbourne Central, 211 La Trobe St -37.810279  144.962921
#  29                    458-460 Bridge Road -37.819329  145.006710
#  30                           Dorcas St 18 -37.830430  144.969582
#  31                           56 Chapel St -37.855790  144.992800
#  32                      458-460 Bridge Rd -37.819396  145.006985
#  33                                    NaN -37.782392  144.977753
#  34                            Flinders La -37.816466  144.967076
#  35                           Lygon Street -37.803408  144.966494
#  36                             Russell St -37.812633  144.968091
#  37                                    NaN -37.809033  144.970833
#  38                                    NaN -37.846252  144.992850
#  39                                    NaN -37.813299  144.943285
#  40                               Lygon St -37.803568  144.966473
#  61                            LAZEZZA
#  62                             Kazbah
#  63         Station Café Kebab & Pizza
#  64           Fez & Co (Kitchen & Bar)
#  65           Uni Bros Kebabs & Pizzas
#  66                          El Jannah
#  67                          El Jannah
#  68                   Café on Johnston
#  69         The Valley Lebanese Bakery
#  70                          Jasmine 1
#  71                   Sahra Restaurant
#  72                          El Jannah
#  73                   Farsi Restaurant
#  74                          El Jannah
#  75                              Zahli
#  76                         Al Barakeh
#  77                             Jasmin
#  78           HC Hawa Charcoal Chicken
#  79         Cedrus Lebanese Restaurant
#  80                      El-Phoenician
#  81                         Jaam e Jam
#  82                      El-Phoenician
#  83             Awafi Charcoal Chicken
#  84                           Al Aseel
#  85                            La Mono
#  86                          El Jannah
#  87                           Thievery
#  88                    Kadmus Lebanese
#  89                              Zaida
#  90                   Lebanon & Beyond
#  91            Oricco Charcoal Chicken
#  92                           El Karim
#  93        Frank's Lebanese Restaurant
#  94                          El Jannah
#  95                  Savion Restaurant
#  96            Persian Rose Restaurant
#  97                   Emma's Snack Bar
#  98            Inflames Charcoal Grill
#  99       Fatima's Lebanese Restaurant
#
#                                         Address        Lat         Lng
#  0                           325 Canterbury Rd. -33.914910  151.112472
#  1                                950 Botany Rd -33.930711  151.194350
#  2                         Shop 3, 490 Crown St -33.886646  151.213736
#  3                             315 Princes Hwy. -33.945028  151.141616
#  4                                  82 Hall St. -33.889338  151.270772
#  5                             71-73 Spring St. -33.892537  151.248629
#  6                                      Gateway -33.862234  151.210333
#  7                          199A Canterbury Rd. -33.933791  151.026687
#  8                                          NaN -33.870477  151.209396
#  9                               Canterbury Rd. -33.913883  151.115287
#  10                                15 Auburn Rd -33.850554  151.033105
#  11                          4/173 Waterloo Rd. -33.906273  151.057615
#  12                                 75 South St -33.834597  151.010994
#  13                Level 7 - Westfield, Pitt St -33.870220  151.208400
#  14                              354 George St. -33.809600  151.005233
#  15                             309 Forest Road -33.965270  151.098950
#  16                              101 Burwood Rd -33.874514  151.104202
#  17                               Cleveland St. -33.891711  151.214545
#  18                            379 Liverpool St -33.878175  151.220478
#  19                              49 Raymond St. -33.919660  151.036737
#  20                             201 Hamilton Rd -33.873141  150.937859
#  21                          163 Glenayr Avenue -33.888180  151.270800
#  22                         249 Annangrove Road -33.657623  150.931623
#  23                          224 The Boulevarde -33.925854  151.056640
#  24                                    Union St -33.870114  151.197548
#  25                                  Church St. -33.793274  150.999544
#  26                               179 Enmore Rd -33.898969  151.172240
#  27                               30 Argyle Ave -33.813731  151.109573
#  28                            Westfield Sydney -33.870310  151.209403
#  29                          53 Erskineville Rd -33.899455  151.183452
#  30                         49 Erskineville Rd. -33.899510  151.182910
#  31                        Westfield Parramatta -33.817256  151.004380
#  32                               129 Enmore Rd -33.898831  151.173655
#  33                             126 Burwood Rd. -33.875168  151.104070
#  34                                290 Crown St -33.880096  151.215138
#  35                                  MLC Centre -33.868144  151.209259
#  36                                         NaN -33.883815  150.924573
#  96                       1380-1388 Pacific Hwy -33.733826  151.126880
#  97                               59 Liberty St -33.895982  151.171223
#  98                             Old Northern Rd -33.734520  151.003588
#  99                        294-296 Cleveland St -33.890237  151.208675  }

# %%
df_venues.keys()
# Out:
# dict_keys(['Sydney, NSW', 'Melbourne, VIC', 'Perth, WA', 'Canberra, ACT', 'Brisbane, QLD'])

# %% [markdown]
# # **As we can see above, we have 5 keys of 5 cities, so, for maps we can either use their index numbers 0,1,2,3 and 4 respectively or simply their names. Moreover, we will plot our data on the maps for respective cities**

# %%
maps = {}
for city in cities:
    city_lat = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[city] = folium.Map(location=[city_lat, city_lng], zoom_start=11)

    # add markers to map
    for lat, lng, label in zip(df_venues[city]['Lat'], df_venues[city]['Lng'], df_venues[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(maps[city])

# %%
maps[cities[0]] #Sydney
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[1]] #Melbourne
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[2]] #Perth
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[3]] #Canberra
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[4]] #Brisbane
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # **Now that we can see the restaurant clusters on the maps for each city, and might see that Sydney and Melbourne might be the best option, we need to do indepth analysis. This is because Sydney is has a bigger Central Business District compared to other cities, and, therefore, the cluster might no present the true picture. Hence, we will take the central point of each city and calculate the mean distance between the center and all the locations**

# %%
maps = {}
for city in cities:
    city_lat = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    city_lng = np.mean([results[city]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        results[city]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[city] = folium.Map(location=[city_lat, city_lng], zoom_start=11)
    venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 
    # add markers to map
    for lat, lng, label in zip(df_venues[city]['Lat'], df_venues[city]['Lng'], df_venues[city]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(maps[city])
        folium.PolyLine([venues_mean_coor, [lat, lng]], color="orange", weight=1.5, opacity=0.5).add_to(maps[city])
    
    label = folium.Popup("Mean Co-ordinate", parse_html=True)
    folium.CircleMarker(
        venues_mean_coor,
        radius=10,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(maps[city])

    print(city)
    print("Mean Distance from Mean coordinates")
    print(np.mean(np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)))
# Out:
# Sydney, NSW
# Mean Distance from Mean coordinates
# 0.11600453159957849
# Melbourne, VIC
# Mean Distance from Mean coordinates
# 0.037171818747818525
# Perth, WA
# Mean Distance from Mean coordinates
# 0.04414071939304621
# Canberra, ACT
# Mean Distance from Mean coordinates
# 0.07499200150714927
# Brisbane, QLD
# Mean Distance from Mean coordinates
# 0.0646339126548971

# %%
maps[cities[0]] #SYDNEY
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[1]] #MELBOURNE
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[2]] #PERTH
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[3]] #CANBERRA
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[cities[4]] #BRISBANE
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **In the steps below, we remove maximum outliers from all  the values to get an average value minus the outliers. The following values are achieved which show that Melbourne has the least distance from central point to explore Middle Eastern restaurants in the city:**
#
#
# **Sydney, NSW**
#
# Mean Distance from Mean coordinates: 0.11287612594187721
#
# **Canberra, ACT**
#
# Mean Distance from Mean coordinates: 0.07047281616415198
#
# **Melbourne, VIC**
#
# Mean Distance from Mean coordinates: 0.03318223070418223
#
# **Perth, WA**
#
# Mean Distance from Mean coordinates: 0.04176312230297355
#
# **Brisbane, QLD**
#
# Mean Distance from Mean coordinates: 0.05986191980294174

# %%
city = 'Sydney, NSW'
venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 

print(city)
print("Mean Distance from Mean coordinates")
dists = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)
dists.sort()
print(np.mean(dists[:-1]))
# Out:
# Sydney, NSW
# Mean Distance from Mean coordinates
# 0.11287612594187721

# %%
city = 'Canberra, ACT'
venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 

print(city)
print("Mean Distance from Mean coordinates")
dists = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)
dists.sort()
print(np.mean(dists[:-1]))
# Out:
# Canberra, ACT
# Mean Distance from Mean coordinates
# 0.07047281616415198

# %%
city = 'Melbourne, VIC'
venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 

print(city)
print("Mean Distance from Mean coordinates")
dists = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)
dists.sort()
print(np.mean(dists[:-1]))
# Out:
# Melbourne, VIC
# Mean Distance from Mean coordinates
# 0.03318223070418223

# %%
city = 'Perth, WA'
venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 

print(city)
print("Mean Distance from Mean coordinates")
dists = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)
dists.sort()
print(np.mean(dists[:-1]))
# Out:
# Perth, WA
# Mean Distance from Mean coordinates
# 0.04176312230297355

# %%
city = 'Brisbane, QLD'
venues_mean_coor = [df_venues[city]['Lat'].mean(), df_venues[city]['Lng'].mean()] 

print(city)
print("Mean Distance from Mean coordinates")
dists = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coor),1,df_venues[city][['Lat','Lng']].values)
dists.sort()
print(np.mean(dists[:-1]))
# Out:
# Brisbane, QLD
# Mean Distance from Mean coordinates
# 0.05986191980294174
